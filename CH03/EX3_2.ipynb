# %% [markdown]
# # Exercise 3.2: Curve plotting
#
# Although the plot function is designed primarily for plotting standard $xy$ graphs, it can be adapted for other kinds of plotting as well.

# %% [markdown]
# a)
# Make a plot of the so-called _deltoid_ curve, which is defined parametrically by the equations
#
# $$ x = 2\cos\theta + \cos2\theta,  y = 2 \sin\theta - \sin2\theta$$
#
# where $0 \leq \theta \lt 2\pi$. Take a set of values of $\theta$ between zero and $2\pi$ and calculate $x$ and $y$ for each of the equations above, then plot $y$ as a function of $x$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
theta = np.linspace(0, 2*np.pi, 1000)
x = 2*np.cos(theta) + np.cos(2*theta)
y = 2*np.sin(theta) - np.sin(2*theta)

max_val = 4

plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.xlim([-max_val, max_val])
plt.ylim([-max_val, max_val])
plt.title("Deltoid Curve")
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# b)
# Taking this approach a step further, one can make a polar plot $r = f(\theta)$ for some function $f$ by calculating $r$ for a range of values of $\theta$ and then converting $r$ and $\theta$ to Cartesian coordinates using the standard equations $x = r\cos\theta$, $y = r\sin\theta$. Use this method to make a plot of the Galilean spiral:
# $$ r = \theta^2$$
# for $0 \leq \theta \leq 10\pi$

# %%
theta = np.linspace(0, 10*np.pi, 1000)
x = theta**2 * np.cos(theta)
y = theta**2 * np.sin(theta)
max_val = 1200

plt.figure(figsize=(10, 10))
plt.plot(x,y)
plt.xlim([-max_val, max_val])
plt.ylim([-max_val, max_val])
plt.title("Galilean spiral")
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# c)
# Using the same method, make a polar plot of "Fey's function"
#
# $$r = e^{\cos\theta} - 2 \cos 4\theta + \sin^5 \frac{\theta}{12}$$
# in the range $0 \leq \theta \leq 24\pi$

# %%
theta = np.linspace(0, 24*np.pi, 10000)
r = np.exp(np.cos(theta)) - 2*np.cos(4*theta) + np.sin(theta/12)**5
x = r * np.cos(theta)
y = r * np.sin(theta)

max_val = 5

plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.xlim([-max_val, max_val])
plt.ylim([-max_val, max_val])
plt.title("Fey's Function")
plt.gca().set_aspect('equal')
plt.show()
